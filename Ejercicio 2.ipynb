# %%
# read web table into pandas DF
import pandas as pd


ciaLink1='https://www.cia.gov/the-world-factbook/field/carbon-dioxide-emissions/country-comparison'
carbon=pd.read_html(ciaLink1, # link
                        header=0, # where is the header?
                        flavor='bs4')[0] # and which table?

# %%
carbon
# Out:
#      Rank                                           Pays          CO2  \
# 0       1                                          China  13506000000
# 1       2                                  United States   4941000000
# 2       3                                          India   2805000000
# 3       4                                         Russia   1840000000
# 4       5                                          Japan   1049000000
# ..    ...                                            ...          ...
# 213   214                                     Montserrat        26000
# 214   215  Saint Helena, Ascension, and Tristan da Cunha        13000
# 215   216                                     Antarctica        12000
# 216   217                                           Niue         8000
# 217   218                       Northern Mariana Islands            0
#
#           Date
# 0    2022 est.
# 1    2022 est.
# 2    2022 est.
# 3    2022 est.
# 4    2022 est.
# ..         ...
# ...

# %% [markdown]
# # Quel type de données

# %%
print(carbon.CO2.dtype)
# Out:
# int64

# %% [markdown]
# # Supprimer *colonne*

# %%
carbon=carbon.drop(columns=['Rank'])

# %% [markdown]
# # **Renommer**

# %%
carbon = carbon.rename(columns={
    'Country': 'Pays','metric tonnes of CO2':'CO2','Date of Information':'Date'})
carbon
# Out:
#                                               Pays          CO2       Date
# 0                                            China  13506000000  2022 est.
# 1                                    United States   4941000000  2022 est.
# 2                                            India   2805000000  2022 est.
# 3                                           Russia   1840000000  2022 est.
# 4                                            Japan   1049000000  2022 est.
# ..                                             ...          ...        ...
# 213                                     Montserrat        26000  2022 est.
# 214  Saint Helena, Ascension, and Tristan da Cunha        13000  2022 est.
# 215                                     Antarctica        12000  2022 est.
# 216                                           Niue         8000  2022 est.
# 217                       Northern Mariana Islands            0  2019 est.
#
# [218 rows x 3 columns]

# %% [markdown]
# # Détecter des trucs, remplacer des symboles

# %% [markdown]
# Liste tout ce qui commence qui commence ou fini par un espace

# %%
carbon.Pays[carbon.Pays.str.contains(pat=r'(^\s|\s$)')]
# Out:
# <ipython-input-81-6e54413014e4>:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   carbon.Pays[carbon.Pays.str.contains(pat=r'(^\s|\s$)')]
# 4     Test
# Name: Pays, dtype: object

# %% [markdown]
# remplace mais ça marche pas

# %%
carbon.Pays.str.replace(pat=r'(^\s|\s$)',repl='', regex=True)
# Out:
# 0                                              China
# 1                                      United States
# 2                                              India
# 3                                             Russia
# 4                                               Test
#                            ...
# 213                                       Montserrat
# 214    Saint Helena, Ascension, and Tristan da Cunha
# 215                                       Antarctica
# 216                                             Niue
# 217                         Northern Mariana Islands
# Name: Pays, Length: 218, dtype: object

# %%
carbon.Pays[carbon.Pays.str.contains(pat=r'(^\s|\s$)')]
# Out:
# <ipython-input-92-6e54413014e4>:1: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   carbon.Pays[carbon.Pays.str.contains(pat=r'(^\s|\s$)')]
# 4     Test
# Name: Pays, dtype: object

# %% [markdown]
# **enleve les caractère spéciaux dans des cononne de nombre avant de les passer en float mais la ca marche pas c'est déjà en float**
# ```

# %%
carbon.co2[carbon.CO2.str.contains(r'[^0-9.-]')]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-97-dc4112a25a2c> in <cell line: 1>()
# ----> 1 mask=carbon.CO2.contains(r'[^0-9.-]')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'Series' object has no attribute 'contains'

# %% [markdown]
# # Enlever les espace au début et à la fin uniquement sur les séries object

# %% [markdown]
# marche pas

# %%
carbon.Pays.str.strip()
carbon.Date.str.strip()
# Out:
# 0      2022 est.
# 1      2022 est.
# 2      2022 est.
# 3      2022 est.
# 4      2022 est.
#          ...
# 213    2022 est.
# 214    2022 est.
# 215    2022 est.
# 216    2022 est.
# 217    2019 est.
# Name: Date, Length: 218, dtype: object

# %% [markdown]
# chercher tous ceux en deux mots

# %%
carbon.Pays[carbon.Pays.str.contains(pat=r' ')]
# Out:
# 1                                      United States
# 4                                               Test
# 8                                       Korea, South
# 9                                       Saudi Arabia
# 12                                      South Africa
# 15                                  Turkey (Turkiye)
# 16                                    United Kingdom
# 23                              United Arab Emirates
# 44                                         Hong Kong
# 53                                      Korea, North
# 68                               Trinidad and Tobago
# 70                                       New Zealand
# 74                                Dominican Republic
# 77                            Bosnia and Herzegovina
# 81                                         Sri Lanka
# 90                                       Puerto Rico
# 100                                    Cote d'Ivoire
# 115                                      El Salvador
# ...

# %% [markdown]
# Extraire les nombres d'une colone

# %%
carbon.Date=carbon.Date.str.extract(pat=r'(\d+)', expand=False)
carbon
# Out:
#                                               Pays          CO2  Date
# 0                                            China  13506000000  2022
# 1                                    United States   4941000000  2022
# 2                                            India   2805000000  2022
# 3                                           Russia   1840000000  2022
# 4                                            Japan   1049000000  2022
# ..                                             ...          ...   ...
# 213                                     Montserrat        26000  2022
# 214  Saint Helena, Ascension, and Tristan da Cunha        13000  2022
# 215                                     Antarctica        12000  2022
# 216                                           Niue         8000  2022
# 217                       Northern Mariana Islands            0  2019
#
# [218 rows x 3 columns]

# %%
carbon.Date = carbon.Date.astype(int)
type(carbon.Date[0])
# Out:
# numpy.int64
